# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 177.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 186.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 148.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 123.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 169.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
 df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
duplicated_rows = df[df.duplicated()] 
len(duplicated_rows)
# Out:
# 0

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
duplicated_rows = df[df.duplicated(subset=['MainBranch', 'Employment','RemoteWork'])]
len(duplicated_rows)

duplicated_rows = df[df.duplicated(subset=['MainBranch', 'Employment', 'RemoteWork'], keep=False)]


for column in df.columns:
    if column not in ['MainBranch', 'Employment', 'RemoteWork']:
       
        print(f"\nAnalysis of column: {column}")
        print(duplicated_rows.groupby(column).size())
# Out:
# Analysis of column: ResponseId
# ResponseId
# 1        1
# 2        1
# 3        1
# 4        1
# 5        1
#         ..
# 65433    1
# 65434    1
# 65435    1
# 65436    1
# 65437    1
# Length: 65270, dtype: int64
#
# Analysis of column: Age
# Age
# 18-24 years old       14047
# 25-34 years old       23876
# 35-44 years old       14920
# 45-54 years old        6241
# 55-64 years old        2565
# 65 years or older       753
# Prefer not to say       318
# Under 18 years old     2550
# dtype: int64
#
# Analysis of column: Check
# Check
# Apples    65270
# dtype: int64
#
# Analysis of column: CodingActivities
# CodingActivities
# Bootstrapping a business                                                                                                819
# Bootstrapping a business;Freelance/contract work                                                                        308
# ...

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
# !pip install seaborn
import pandas as pd
import matplotlib.pyplot as plt




duplicated_rows = df[df.duplicated(subset=['MainBranch', 'Employment', 'RemoteWork'], keep=False)]

plt.figure(figsize=(12, 6))  
country_counts = duplicated_rows['Country'].value_counts()


top_country_counts = country_counts.head(10)

plt.bar(top_country_counts.index, top_country_counts.values, color='skyblue')
plt.title('Distribution of Duplicates by Country')
plt.xlabel('Country')
plt.ylabel('Count of Duplicates')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  
plt.show()


plt.figure(figsize=(8, 8))  
employment_counts = duplicated_rows['Employment'].value_counts()


total_duplicates = employment_counts.sum()


threshold = 0.05
small_categories = employment_counts[employment_counts / total_duplicates < threshold]


employment_counts = employment_counts[employment_counts / total_duplicates >= threshold]
employment_counts['Other'] = small_categories.sum()


plt.pie(employment_counts, labels=employment_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors[:len(employment_counts)])
plt.title('Distribution of Duplicates by Employment')
plt.axis('equal')  
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
subset_columns = ['MainBranch', 'Employment', 'RemoteWork']


df_no_duplicates = df.drop_duplicates(subset=subset_columns, keep='first')


print(f"Original DataFrame shape: {df.shape}")
print(f"DataFrame shape after removing duplicates: {df_no_duplicates.shape}")
# Out:
# Original DataFrame shape: (65437, 114)
# DataFrame shape after removing duplicates: (561, 114)

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# Objective:The goal is to identify and remove duplicate rows in the dataset to ensure that only unique records remain based on specific criteria, preventing redundant or misleading analysis.
# Step 1:
# Define Critical Columns for Uniqueness
# Action: Determine which columns are essential for identifying duplicates. In this case, we focus on columns that define the uniqueness of a job profile.
# Chosen Columns: Main Branch, Employment, and Remote Work are selected as the critical columns, as they define a respondent's job profile.
# Step 2:
# Identify Existing Duplicates
# Action: Identify duplicate rows based on the selected critical columns.
# To check for duplicates based on the subset of columns (Main Branch, Employment, Remote Work).
# Step 3:
# Remove Duplicates Based on Critical Columns
# Action: Remove duplicates by keeping the first occurrence of each unique combination of the critical columns.
# Step 4:
# Validate the Results
# Action: Ensure the removal of duplicates has been successful and validate the dataset.
# Step 5:
# Document the Changes Made
# Action: Record the actions taken during the process for transparency and reproducibility.
# Conclusion
# The process of identifying and removing duplicates involved analyzing the dataset for redundant records based on a subset of critical columns. By removing rows with identical job profiles (defined by Main Branch, Employment, and Remote Work),  ensured the dataset reflects unique respondents. This process enhances the quality and reliability of the data for further analysis.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# The choice of MainBranch, Employment, and RemoteWork for identifying and removing duplicates is driven by the goal of maintaining relevant job profiles while ensuring the dataset remains clean and focused. These columns provide essential information that defines the uniqueness of each record in the context of job-related analysis, while avoiding the removal of important, non-redundant variations in other columns (such as age or country). By focusing on these critical columns, we maintain the integrity and usability of the dataset for further analysis and insights.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
